# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
a = [1,2,3]

# %%
plt.plot(a)

# %%
plt.show()

# %%
b = [4,5,6]

# %%
plt.plot(a,b)

# %%
# %matplotlib inline

# %%
plt.plot(a,b)

# %%
# %timeit np.arange(10)
# Out:
# 597 ns ± 12.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
plt.plot(a,b, '*')

# %%
plt.plot(a,b,'r--')

# %%
c =[10, 8, 6]

# %%
d = [1,8,3]

# %%
plt.plot(a,b, 'r--',c,d, 'b*')
# Out:
# [<matplotlib.lines.Line2D at 0x120134cc0>,
#  <matplotlib.lines.Line2D at 0x120134e10>]

# %%
t = np.arange(0.0, 2.0, 0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s)

# %%
plt.plot(t, s,'r--', label='aaaa')
plt.plot(t*2,s,'b--', label='bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
