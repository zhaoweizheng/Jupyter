# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import normal, rand
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
a = np.linspace(0, 10, 100)
print(a)
b = np.exp(-a)
plt.plot(a, b)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %%
plt.plot?

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8, 0.8])
a = np.linspace(0,10,100)
b = np.exp(-a)
ax.plot(a,b)

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
x = normal(size=200)
ax.hist(x, bins=30)
# Out:
# (array([ 1.,  0.,  1.,  4.,  3.,  2.,  8.,  2.,  6.,  7., 12., 11., 16.,
#         18., 13., 10., 15., 11., 10., 10.,  8.,  8.,  5.,  6.,  2.,  5.,
#          2.,  1.,  2.,  1.]),
#  array([-2.51789193, -2.34736202, -2.17683211, -2.0063022 , -1.83577229,
#         -1.66524238, -1.49471247, -1.32418255, -1.15365264, -0.98312273,
#         -0.81259282, -0.64206291, -0.471533  , -0.30100309, -0.13047318,
#          0.04005674,  0.21058665,  0.38111656,  0.55164647,  0.72217638,
#          0.89270629,  1.0632362 ,  1.23376611,  1.40429603,  1.57482594,
#          1.74535585,  1.91588576,  2.08641567,  2.25694558,  2.42747549,
#          2.5980054 ]),
#  <a list of 30 Patch objects>)

# %%
x = np.arange(0, 5, 0.02)
y = np.exp(-x) * np.cos(2*np.pi*x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid(color='red')

# %%
fig, ax = plt.subplots(3,3,sharex='col', sharey='row')

# %%
fig = plt.subplots(3,3)

# %%
n = 1024
x = np.random.normal(0,1,n)
y = np.random.normal(0,1,n)
plt.scatter(x,y)

# %%
cities = pd.read_csv('Desktop/city_population.csv')
city
# Out:
#     name      area  population   longd   latd
# 0    南京市   6582.31     8004680  118.78  32.04
# 1    无锡市   4787.61     6372624  120.29  31.59
# 2    徐州市  11764.88     8580500  117.20  34.26
# 3    常州市   4384.57     4591972  119.95  31.79
# 4    苏州市   8488.42    10465994  120.62  31.32
# 5    南通市   8001.00     7282835  120.86  32.01
# 6   连云港市   7615.29     4393914  119.16  34.59
# 7    淮安市   9949.97     4799889  119.15  33.50
# 8    盐城市  16972.42     7260240  120.13  33.38
# 9    扬州市   6591.21     4459760  119.42  32.39
# 10   镇江市   3840.32     3113384  119.44  32.20
# 11   泰州市   5787.26     4618558  119.90  32.49
# 12   宿迁市   8555.00     4715553  118.30  33.96

# %%
cities = pd.read_csv('Desktop/city_population.csv')


lat = cities['latd']
lon = cities['longd']
population = cities['population'],
area = cities['area']

plt.scatter(lon, lat, label=None, c=np.log10(population)[0], cmap="viridis", s=area/10, linewidths=0, alpha=0.5)    
plt.axis(aspect='equal')
plt.xlabel("longitude")
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')    
plt.title('江苏省各城市面积和人口')
for area in [10, 30, 50]:
    plt.scatter([], [], c='k', alpha=0.3, s=area, label=str(area) + ' km$^2$')

plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

# %%
np.random.seed(19680801)

x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Leprechauns")
plt.ylabel("Gold")
plt.legend(loc='upper left')
plt.title('树叶')
# Out:
# Text(0.5, 1.0, '树叶')

# %%
np.random.seed(19680801)

# 点的面积和色彩
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar') 
ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %%
position = ['apple', 'facebook', 'google', 'huawei', 'alibaba']
data = [56, 65, 98, 73, 86]
plt.bar(x=position, height=data)
# Out:
# <BarContainer object of 5 artists>
